# %% [markdown]
# # Performance Comparison

# %% [markdown]
# <div id="tocheading">Table of Contents</div>
# <div id="toc"></div>

# %% [markdown]
# Difference between the search algorithms will be judged on the following grid
# ```
# Initial State:
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# ```

# %% [markdown]
# #### Summary
#
# This table summarizes the performances. Detailed comparison on optimality and completness can be found below
#
# - The least number of nodes expanded: A* with number of walkers
# - The greatest number of nodes expanded: Iterative Deepening
# - The least path cost: Breadth First
# - The greatest path cost: Depth First
#
#
# | Search Strategy                     | Nodes Expanded | Solution Cost |
# |-------------------------------------|----------------|---------------|
# | Breadth First                       | 186            | 49            |
# | Depth First                         | 216            | 92            |
# | Iterative Deepening                 | 75802          | 70            |
# | Uniform Cost                        | 165            | 53            |
# | Greedy with number of walkers       | 269            | 81            |
# | Greedy with sum of walker distances | 373            | 75            |
# | Greedy with nearest walker distance | 1k+            | ∞             |
# | A* with number of walkers           | 150            | 54            |
# | A* with sum of walker distances     | 155            | 61            |
# | A* with nearest walker distance     | 1k+            | ∞             |

# %% [markdown]
# #### Breadth First Search
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
#
# ```
# - Total number of expanded nodes: 186
# - Total solution path cost: 49

# %% [markdown]
# as we can see from the stack trace, the path the agent took to the dragon stone is not optimal at all. However, the algorithm is complete.

# %% [markdown]
# #### Depth First Search
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][J][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [J][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][J][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 216
# - Total solution path cost: 92

# %% [markdown]
# The path is not optimal
#
# The algorithm is not complete in general but found the solution in this case
#
# Has higher expanded nodes than BFS

# %% [markdown]
# #### Uniform Cost Search
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][J][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 165
# - Total solution path cost: 53

# %% [markdown]
# Uniform cost search is complete and optimal since it considers path cost and as you can see it tried to minimize the number of steps it was trying to take it has the least number of nodes expanded so far

# %% [markdown]
# #### Iterative Deepening
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][J][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [J][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [J][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [J][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][J][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 7582
# - Total solution path cost: 70

# %% [markdown]
# The search is complete and not optimal and it has the most number of expanded nodes since it is an iterative solution

# %% [markdown]
# #### Greedy Search using number of walkers heuristic
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][J][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][J][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][J][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][J][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][J][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [J][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [J][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 269
# - Total solution path cost: 81

# %% [markdown]
# This is the simplest heuristic and thus the least optimal. The search is complete and the expanded nodes is very high

# %% [markdown]
# #### Greedy Search using sum of distances to walkers heuristic
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 373
# - Total solution path cost: 75

# %% [markdown]
# Greedy is not optimal since it doesnt take the path cost into consideration. The search is complete the number of the exoanded nodes is high

# %% [markdown]
# #### Greedy Search nearest walker heuristic
# Terminated the search when it reached 800 expanded nodes. The heuristic is to balem

# %% [markdown]
# #### A* using number of walkers heuristic
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [J][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [J][ ][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [J][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][W]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][J]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 150
# - Total solution path cost: 54

# %% [markdown]
# Has the least number of expanded nodes. The algorithm is optimal since considers path cost and complete.

# %% [markdown]
# #### A* using sum of walkers distances heuristic
# ```
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][J][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [J][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [W][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [J][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][J][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][W][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][J][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][J][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][J][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][J][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][W]
# 2 [ ][W][ ][J][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][J][W]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][J][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][J]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][W][ ][ ][J]
# 3 [ ][ ][ ][ ][W]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][W][ ][ ][J]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][J]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][J]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][J][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][J][ ][ ]
# 1 [W][ ][ ][ ][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][ ][J][ ][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [W][J][ ][ ][ ]
# 2 [ ][W][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [ ][J][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ]
# 5 [D][ ][ ][X][ ]
# 6 [ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ]
# ```
# - Total number of expanded nodes: 155
# - Total solution path cost: 61

# %% [markdown]
# This heuristic has a unique take on the how to kill the white. However optimal and complete. Has the second least number of expanded nodes

# %% [markdown]
# #### A* using nearest walker distance heuristic
# Terminated the search when it reached 100 expanded nodes

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')
