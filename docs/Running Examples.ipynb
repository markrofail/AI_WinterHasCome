# %% [markdown]
# ### Running Examples

# %% [markdown]
# <div id="tocheading">Table of Contents</div>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# #### Breadth First Search Examples
#
# ##### Example 1:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][ ][X][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [X][ ][ ][ ][X][ ][ ][X]
# 3 [ ][X][ ][ ][X][ ][ ][W]
# 4 [ ][ ][ ][ ][ ][ ][W][D]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][X][ ][ ][ ][ ][ ][J]
#
# Total number of expanded nodes: 10
# Total solution path cost: 7
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][ ][X][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [X][ ][ ][ ][X][ ][ ][X]
# 3 [ ][X][ ][ ][X][ ][ ][W]
# 4 [ ][ ][ ][ ][ ][ ][W][D]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][X][ ][ ][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][ ][X][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [X][ ][ ][ ][X][ ][ ][X]
# 3 [ ][X][ ][ ][X][ ][ ][W]
# 4 [ ][ ][ ][ ][ ][ ][W][D]
# 5 [ ][ ][ ][ ][ ][ ][ ][J]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][ ][X][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [X][ ][ ][ ][X][ ][ ][X]
# 3 [ ][X][ ][ ][X][ ][ ][W]
# 4 [ ][ ][ ][ ][ ][ ][W][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][ ][X][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [X][ ][ ][ ][X][ ][ ][X]
# 3 [ ][X][ ][ ][X][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# ```
#
# ##### Example 2:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][W][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][J]
#
# Total number of expanded nodes: 312949
# Total solution path cost: 36
# Solution Trace:
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][W][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][W][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][J][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][W][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][J][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][W][X]
# 3 [X][W][X][J][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][W][X][J][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][J][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][J][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][W]
# 1 [ ][ ][X][ ][J]
# 2 [ ][ ][ ][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][J]
# 2 [ ][ ][ ][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][J][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][J][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][J][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][J][ ][ ][X]
# 3 [X][W][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][J][ ][ ][X]
# 3 [X][ ][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][J][X][ ][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][ ][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][J][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][ ][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][J][ ][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][ ][ ][X]
# 3 [X][ ][X][ ][ ]
# 4 [ ][ ][X][D][X]
# 5 [ ][ ][ ][ ][ ]
# ```

# %% [markdown]
# #### Depth First Search Examples
#
# ##### Example 1:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D
# 0 [ ][ ][W][ ]
# 1 [ ][X][W][X]
# 2 [ ][ ][ ][W]
# 3 [X][ ][X][ ]
# 4 [W][ ][D][ ]
# 5 [ ][W][X][J]
# ```
# Runs forever and doesn't terminate since it returns to a previously visited node
#
# ##### Example 2:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D
# 0 [W][X][ ][W]
# 1 [X][W][X][ ]
# 2 [ ][X][ ][W]
# 3 [W][W][D][ ]
# 4 [ ][ ][ ][J]
# ```
# Runs forever and doesn't terminate since it returns to a previously visited node

# %% [markdown]
# #### Depth First Search Examples
# ##### Example 1:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][D]
# 2 [ ][X][W][ ][ ]
# 3 [ ][ ][ ][ ][J]
#
# Total number of expanded nodes: 130
# Total solution path cost: 11
# Solution Trace:
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][D]
# 2 [ ][X][W][ ][ ]
# 3 [ ][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][D]
# 2 [ ][X][W][ ][J]
# 3 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][J]
# 2 [ ][X][W][ ][ ]
# 3 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][D]
# 2 [ ][X][W][ ][J]
# 3 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][W][D]
# 2 [ ][X][W][J][ ]
# 3 [ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][D]
# 2 [ ][X][ ][J][ ]
# 3 [ ][ ][ ][ ][ ]
#
# ```
# ##### Example 2:
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][J]
#
# Total number of expanded nodes: 9720
# Total solution path cost: 22
# Solution Trace:
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][J]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][ ][ ]
# 3 [X][ ][ ][ ][J]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][ ][J]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][D][J][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][W][J][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][J][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][J][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][ ][W][X][ ]
# 1 [ ][J][X][ ][ ]
# 2 [ ][ ][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][J][W][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [ ][J][ ][X][ ]
# 1 [ ][ ][X][ ][ ]
# 2 [ ][ ][D][ ][ ]
# 3 [X][ ][ ][ ][ ]
# 4 [X][X][X][X][ ]
# 5 [X][ ][ ][ ][ ]
#
# ```

# %% [markdown]
# #### Greedy Search using Number of White Walkers heuristic
# ##### Example 1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][J]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][J][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][J][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][J][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][J][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][J][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][J][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][J][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [J][ ][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [J][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][W][ ][ ][X]
# 4 [D][J][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][J][W][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][X]
# 4 [D][ ][X][J][ ][ ]
# 5 [ ][ ][W][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][W][J][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][X][X]
# 1 [ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][X]
# 4 [D][ ][X][ ][ ][ ]
# 5 [ ][ ][ ][J][ ][ ]
# ```
#
# ##### Example 2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [W][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][J]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [W][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][J][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [W][ ][ ][W]
# 4 [ ][X][J][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [W][ ][J][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [W][J][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [ ][J][X][ ]
# 3 [W][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [W][ ][X][W]
# 2 [J][ ][X][ ]
# 3 [W][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [J][ ][X][ ]
# 3 [ ][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][J][X][ ]
# 3 [ ][ ][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][J][ ][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][ ][J][W]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][ ][J][ ]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][ ][ ][ ]
# 4 [ ][X][J][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][ ][ ][ ]
# 4 [ ][X][D][J]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][ ]
# 3 [ ][ ][ ][J]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][W]
# 2 [ ][ ][X][J]
# 3 [ ][ ][ ][ ]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [ ][ ][X][ ]
# 2 [ ][ ][X][J]
# 3 [ ][ ][ ][ ]
# 4 [ ][X][D][ ]
# 5 [ ][X][ ][ ]
# ```

# %% [markdown]
# #### Greedy Search using sum of distances to walkers heuristic
# ##### Example1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][ ][W][X]
# 2 [ ][ ][ ][ ]
# 3 [X][ ][ ][D]
# 4 [ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][ ][W][X]
# 2 [ ][ ][ ][ ]
# 3 [X][ ][ ][J]
# 4 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][ ][W][X]
# 2 [ ][ ][ ][ ]
# 3 [X][ ][J][D]
# 4 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][ ][W][X]
# 2 [ ][ ][ ][ ]
# 3 [X][J][ ][D]
# 4 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][ ][W][X]
# 2 [ ][J][ ][ ]
# 3 [X][ ][ ][D]
# 4 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][J][W][X]
# 2 [ ][ ][ ][ ]
# 3 [X][ ][ ][D]
# 4 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][ ][ ]
# 1 [X][J][ ][X]
# 2 [ ][ ][ ][ ]
# 3 [X][ ][ ][D]
# 4 [ ][ ][ ][ ]
# ```
# ##### Example2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][J]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][J]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][J]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][J][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][J][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][J]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][J]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][J]
# 4 [W][W][W][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][ ][J]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][W][ ]
# 4 [W][W][W][J][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][J][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][J]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][J]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][J]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][D][J]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][ ][ ]
# 1 [ ][X][ ][J][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][W][J][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][J][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][J][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][J][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][J][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][J][ ][ ]
# 4 [W][W][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][W][J][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][ ][J][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [W][J][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E
# 0 [X][ ][ ][ ][ ]
# 1 [ ][X][ ][D][ ]
# 2 [ ][X][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][J][ ][ ][ ]
# 5 [ ][X][ ][ ][ ]
# ```

# %% [markdown]
# #### Greedy Search using distance to nearest walker heuristic
# ##### Example1
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E  F
# 0 [W][W][W][W][X][ ]
# 1 [W][ ][ ][ ][X][W]
# 2 [ ][ ][ ][W][D][X]
# 3 [ ][ ][X][ ][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][X][ ][X][ ][J]
# ```
# reaches 1500 expanded nodes and keeps on going forever
#
# ##### Example2
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E
# 0 [ ][ ][X][ ][ ]
# 1 [W][ ][ ][W][ ]
# 2 [ ][W][ ][W][D]
# 3 [ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][J]
# ```
# reaches 1200 expanded nodes and keeps on going forever

# %% [markdown]
# #### Iterative Deepening Search
# ##### Example1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][J]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][J][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][J][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][J][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][J][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [J][ ][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][J][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][J][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][J][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][J][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][J][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][W][ ][ ]
# 1 [X][J][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [ ][ ][ ][ ]
# 1 [X][J][ ][ ]
# 2 [ ][ ][ ][X]
# 3 [ ][ ][ ][ ]
# 4 [D][ ][ ][ ]
# 5 [ ][ ][ ][ ]
# ```
# ##### Example2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][J]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][J][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][J][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][J][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][J][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][J][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][ ]
# 4 [X][X][J][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][J][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][ ]
# 3 [ ][ ][ ][J]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][W]
# 2 [ ][ ][ ][J]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
#
# m→
# n↓ A  B  C  D
# 0 [X][ ][X][ ]
# 1 [X][ ][ ][ ]
# 2 [ ][ ][ ][J]
# 3 [ ][ ][ ][ ]
# 4 [X][X][ ][ ]
# 5 [X][ ][ ][ ]
# 6 [ ][X][ ][ ]
# 7 [ ][D][ ][ ]
# ```

# %% [markdown]
# #### Uniform Cost Search
# ##### Example1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][J][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][J][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][J][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][J][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][J][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][J][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][J][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][J][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][J][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][ ][W][ ][ ][D][ ]
# 2 [ ][ ][ ][J][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][W][ ][ ][ ][ ][ ]
# 1 [X][ ][W][J][W][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][J][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][J][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][J][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][W][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][J][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][J][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][J][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][J][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][J][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][J][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][J][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][J][ ][ ][ ][X]
# 4 [X][ ][ ][W][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][W][J][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][J][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][J][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][J][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][J][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][J][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][J][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][J][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][J][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][J][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][J][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][W][X][ ][ ][ ][ ][ ][ ]
# 1 [X][J][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][X][ ][ ][ ][ ][ ][ ]
# 1 [X][J][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][J][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [J][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [W][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][X][ ][ ][ ][ ][ ][ ]
# 1 [X][ ][ ][ ][ ][ ][ ][D][ ]
# 2 [J][ ][ ][ ][ ][ ][ ][ ][X]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][X]
# 4 [X][ ][ ][ ][ ][ ][ ][ ][ ]
# ```
# ##### Example2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][J][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][J][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][J][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ][W]
# 6 [ ][X][J][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][J][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][J][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][J][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][J][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][J][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][J][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][J][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][W]
# 4 [ ][X][ ][ ][ ][ ][ ][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][W]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][X][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][X][ ][ ][ ][X][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][X][ ][ ][ ][ ][ ][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][X][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ][X][ ]
# 8 [ ][ ][ ][ ][D][ ][ ][ ]
# ```

# %% [markdown]
# #### A* Search using sum of walker distances heuristic
# ##### Example1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][J][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][J][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][J][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][J][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][J][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][J][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][J][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][J][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][J][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][J][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][J][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][J][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][J][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][J][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][J][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][J][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][J][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][W][ ][X][X][ ]
# 6 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][J][W][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ][ ][D][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][J][ ][ ][X][X][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ][ ][ ]
# ```
# ##### Example2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][ ][ ][ ]
# 6 [ ][ ][W][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][J]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][ ][ ][ ]
# 6 [ ][ ][W][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][J]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][ ][ ][ ]
# 6 [ ][ ][W][ ][ ][J]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][ ][ ][ ]
# 6 [ ][ ][W][ ][J][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][ ][ ][ ]
# 6 [ ][ ][W][J][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][D][J][ ][ ]
# 6 [ ][ ][W][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][W][J][ ][ ][ ]
# 6 [ ][ ][W][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][J][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][ ][W][ ][ ]
# 4 [ ][W][J][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][ ][J][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [W][J][ ][W][ ][ ]
# 4 [ ][W][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][J][ ][W][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][W][ ][ ]
# 4 [ ][J][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][W][ ][ ]
# 4 [ ][ ][J][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][W][ ][ ]
# 4 [ ][ ][ ][J][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][J][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J][ ]
# 8 [ ][W][ ][ ][W][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J][ ]
# 8 [ ][W][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ]
# 8 [ ][W][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][J][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][J][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][J][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][J][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][J][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][J]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][J]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][J]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][J][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][J][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][J][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][J][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][J][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][ ][ ][ ][ ]
# 1 [ ][X][J][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][W][J][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][J][ ][ ][ ]
# 1 [ ][X][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][D][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ]
# ```

# %% [markdown]
# #### A* Search using number of walkers heuristic
# ##### Example1
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][J][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][J][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][J][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][J][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][J][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][J][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][J][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][J][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][J][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][J][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
# ```
# ##### Example2
# ```
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][J]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][J][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][J][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][ ][J][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][J][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][J][ ][ ]
# 5 [ ][ ][W][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][ ][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][W][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][W][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][J][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][J][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][J][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][J][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][ ][J][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# 4 [ ][ ][ ][ ][D][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][X][ ][ ]
#
# m→
# n↓ A  B  C  D  E  F  G
# 0 [ ][ ][ ][ ][ ][ ][ ]
# 1 [W][ ][ ][ ][ ][X][ ]
# 2 [ ][J][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][X][ ][ ]
# Initial State:
#  m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][J]
#
# Total number of expanded nodes: 822
# Total solution path cost: 108
# Solution Trace:
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][J]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][J]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][J]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][J][W]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][W]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][J]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][J][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][J][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][J][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][J][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][J][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][J][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][J][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [J][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [W][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [J][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][J][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][J][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][W][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][J][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][J][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][J][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][J][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][J][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][J][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][J][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][J]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][J]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][W][J][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][J][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][J][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][ ][J][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][W][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][J][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
#
# m→
# n↓ A  B  C  D  E  F  G  H  I
# 0 [X][ ][ ][ ][ ][ ][ ][ ][ ]
# 1 [ ][ ][ ][ ][J][ ][ ][ ][ ]
# 2 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 3 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ][ ][D][ ]
# 7 [ ][ ][ ][ ][ ][ ][ ][ ][ ]
# 8 [ ][ ][ ][ ][ ][ ][ ][X][ ]
# ```

# %% [markdown]
# #### A* Search using nearest walker heuristic
# ##### Example1
# ```
# Initial State:
#  m→
# n↓ A  B  C  D  E  F
# 0 [ ][ ][ ][ ][ ][W]
# 1 [ ][ ][ ][ ][ ][X]
# 2 [ ][ ][ ][D][W][ ]
# 3 [W][ ][ ][ ][ ][ ]
# 4 [ ][ ][W][ ][ ][ ]
# 5 [W][ ][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][ ]
# 7 [ ][ ][ ][ ][W][ ]
# 8 [ ][ ][ ][W][ ][J]
# reaches 783 expanded nodes and keeps on going forever
# ```
# ##### Example2
# ```
# n↓ A  B  C  D  E  F  G  H
# 0 [ ][ ][ ][W][ ][X][ ][W]
# 1 [ ][ ][ ][ ][W][ ][ ][W]
# 2 [X][ ][ ][ ][ ][X][ ][ ]
# 3 [ ][X][X][ ][ ][W][X][ ]
# 4 [ ][ ][ ][ ][ ][ ][ ][ ]
# 5 [ ][ ][ ][D][ ][ ][ ][ ]
# 6 [ ][ ][ ][ ][ ][X][ ][J]
# ```
# reaches 875 expanded nodes and keeps on going forever

# %% [markdown]
# #### Search Algorithm
# ##### Example1
#
# ##### Example2
